# %% [markdown]
# <a href="https://colab.research.google.com/github/srikarpantula/fullstack-course4/blob/master/Copy_of_Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Introduction to Pandas
#
# In this video, we’ll explore **Pandas**, a powerful Python library used for handling and analyzing data.
# Pandas makes it easy to work with structured data like tables, Excel sheets, or CSV files.

# %% [markdown]
# ## 🧠 What is Pandas?
#
# **Pandas** is an open-source Python library that allows you to work with structured data very efficiently.
#
# It’s especially useful for working with **tabular data**, which is the most common format in ML projects.
#
# With Pandas, you can read, clean, filter, and analyze your datasets in just a few lines of code.

# %% [markdown]
# ## 🤖 Why Use Pandas in Machine Learning?
#
# Before training any ML model, we must clean and prepare the data.
#
# Pandas helps us:
#
# - Handle missing or incorrect values
# - Rename or modify columns
# - Filter or select data
# - Create new features from existing data
#
# Pandas is your best friend in data preprocessing.

# %% [markdown]
# ## 🔧 Installing Pandas

# %%
# !pip install pandas

# %% [markdown]
# ## 📥 Importing Pandas
#
# Once installed, we import Pandas like this:

# %%
import pandas as pd

# %% [markdown]
# ## 📊 Working with Tabular Data
#
# Pandas mainly works with two data structures:
#
# 1. **Series** – a one-dimensional labeled array (like a single column)
# 2. **DataFrame** – a two-dimensional table (like a full Excel sheet)

# %% [markdown]
# ## 📦 What is a Pandas Series?
#
# A **Series** is a one-dimensional data structure.
# Think of it as a **single column** of data with labels (index).
#
# It stores:
# - A list of values
# - An index (automatically assigned unless you specify it)

# %%
import pandas as pd

# Creating a Series from a list
marks = pd.Series([85, 90, 75])
print(marks)
# Out:
# 0    85
# 1    90
# 2    75
# dtype: int64

# %% [markdown]
# Here,
# - `0`, `1`, `2` → are the default **index labels**
# - `85`, `90`, `75` → are the actual **data values**

# %% [markdown]
# ## 🧱 What is a Pandas DataFrame?
#
# A **DataFrame** is a two-dimensional table — like an **Excel sheet**.
#
# It contains:
# - **Rows** and **Columns**
# - Each column is like a **Series**
# - You can have multiple Series combined into a DataFrame

# %%
data = {
    'Name': ['John', 'Smith', 'Joe'],
    'Marks': [85, 90, 75]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks
# 0   John     85
# 1  Smith     90
# 2    Joe     75

# %% [markdown]
# In this video, we explored the basics of **Pandas**, one of the most important libraries in Python for working with structured data.
#
# We covered:
# - What Pandas is and why it’s useful in machine learning
# - The two core data structures: **Series** and **DataFrame**
# - How to create and view simple tabular data using Pandas
#
# This foundational knowledge sets you up to work with real-world datasets in upcoming lessons.
